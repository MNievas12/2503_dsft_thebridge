# %% [markdown]
# ## Ejercicios de Matplotlib

# %% [markdown]
# 1. Importa pyplot, numpy y pandas

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# 2. Sabemos que podemos pintar gráficas de dos formas: la figura incluye los ejes o teniendo figura y ejes por separado.
#
# Usando solo una figura, usa numpy para los valores del eje X entre 0 y 5.
#
# Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5).
#
# Elige la precisión en el eje X que desees.

# %%
# y = m*x + b

# %%
x = np.linspace(0,5, 2)
x
# Out:
# array([0., 5.])

# %%
# y = m*x + b
# y = 3*x + b
# 0 = 3*0 + b
# b = 0
y1 = 3*x

# %%
plt.plot(x, y1)

# %%
# y = m*x + b
# y = -3*x + b
# -5 = -3*0 + b
# b = -5
y2 = -3*x - 5

# %%
plt.plot(x, y2)

# %%
plt.plot(x, y1)
plt.plot(x, y2)

# %%
plt.subplot(1,2,1)
plt.plot(x, y1)
plt.subplot(1,2,2)
plt.plot(x, y2)

# %%
fig, ax = plt.subplots(1,2)

ax[0].plot(x, y1)
ax[1].plot(x, y2)

# %% [markdown]
# 3. Fija el eje X entre 0 y 5 y el eje Y entre -15 y 15

# %%
plt.subplot(1,2,1)
plt.plot(x, y1)
plt.xlim(0,5)
plt.ylim(-15,15)

plt.subplot(1,2,2)
plt.plot(x, y2)
plt.xlim(0,5)
plt.ylim(-15,15)
# Out:
# (-15.0, 15.0)

# %% [markdown]
# 4. Llama al eje X "eje X", al eje Y "eje Y" y pon de títulos "recta sube" y "recta baja". Muestra dos etiquetas de ejeX pero solo una de eje Y.

# %%
plt.subplot(1,2,1)
plt.plot(x, y1)
plt.xlim(0,5)
plt.ylim(-15,15)
plt.xlabel("Eje x")
plt.ylabel("Eje y")
plt.title("Recta sube")

plt.subplot(1,2,2)
plt.plot(x, y2)
plt.xlim(0,5)
plt.ylim(-15,15)
plt.xlabel("Eje x")
plt.ylabel("Eje y")
plt.title("Recta baja")
plt.tight_layout()

# %% [markdown]
# 5. Usando una figura Y EJES POR SEPARADO, usa numpy para los valores del eje X entre 0 y 5. Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5). Elige la precisión en el eje X que desees.

# %%
# plt.subplot(1,2,1)
# plt.plot(x, y1)
# plt.xlim(0,5)
# plt.ylim(-15,15)
# plt.xlabel("Eje x")
# plt.ylabel("Eje y")
# plt.title("Recta sube")

# plt.subplot(1,2,2)
# plt.plot(x, y2)
# plt.xlim(0,5)
# plt.ylim(-15,15)
# plt.xlabel("Eje x")
# plt.ylabel("Eje y")
# plt.title("Recta baja")
# plt.tight_layout()

# %%
fig, ax = plt.subplots(1,2)

ax[0].plot(x,y1)
ax[0].set_xlim(0,5)
ax[0].set_ylim(-15,15)
ax[0].set_xlabel("Eje x")
ax[0].set_ylabel("Eje y")
ax[0].set_title("Recta sube")

ax[1].plot(x,y2)
ax[1].set_xlim(0,5)
ax[1].set_ylim(-15,15)
ax[1].set_xlabel("Eje x")
ax[1].set_ylabel("Eje y")
ax[1].set_title("Recta baja")

plt.tight_layout()

# %% [markdown]
# 6. Crea una lista de coordenadas X: 20, 22, 24, 26, 28
# Crea una lista de coordenadas Y: 5, 15, -5, 20, 5
# Usa un gráfico de barras colocadas en X con alturas Y

# %%
x = [20, 22, 24, 26, 28]
y = [5, 15, -5, 20, 5]

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# 7. Crea un gráfico de barras. Pintamos la altura de un grupo de amigos, cada barra representa a una persona. Ana mide 160 cm, Luis mide 180 cm, Pedro mide 175 cm, Sofía mide 190 cm, Carmen mide 170 cm. Las barras serán verdes.
# Consejo: si no vas a tener que manipular especialmente los ejes, es más sencillo dejarlos dentro de la figura.

# %%
personas = ["Ana", "Luis", "Pedro", "Sofía", "Carmen"]
alturas = [160, 180, 175, 190, 170]

# %%
plt.bar(personas, alturas, color="#0bb878")
# Out:
# <BarContainer object of 5 artists>

# %%
personas = ["Ana", "Luis", "Pedro", "Sofía", "Carmen"]
alturas = [160, 180, 175, 190, 170]

s_alturas = pd.Series(alturas, index=personas).sort_values(ascending=False)
s_alturas

plt.subplot(1,2,1)
plt.bar(s_alturas.index, s_alturas.values, color="#0bb878")
plt.ylabel("Alturas (cm)")
plt.xlabel("Personas")
plt.title("Comparación de alturas")
# plt.ylim(150,200)

plt.subplot(1,2,2)
plt.bar(s_alturas.index, s_alturas.values, color="#0bb878")
plt.ylabel("Alturas (cm)")
plt.xlabel("Personas")
plt.title("Comparación de alturas")
plt.ylim(150,200)

plt.tight_layout()

# %% [markdown]
# 8. Cambia el tamaño de la figura a (3,5)

# %%
plt.figure(figsize=(3,5))
plt.bar(s_alturas.index, s_alturas.values, color="#0bb878")
plt.ylabel("Alturas (cm)")
plt.xlabel("Personas")
plt.title("Comparación de alturas")
# Out:
# Text(0.5, 1.0, 'Comparación de alturas')

# %% [markdown]
# 9. Basándote en el gráfico anterior, borra la escala del eje Y (ya aparece en la altura)
# Pista: cuando plt.yticks() recibe una lista vacía no pinta el eje Y

# %%
plt.figure(figsize=(3,5))
plt.bar(s_alturas.index, s_alturas.values, color="#0bb878")
plt.ylabel("Alturas (cm)")
plt.xlabel("Personas")
plt.title("Comparación de alturas")
# plt.yticks(np.arange(150,200,10));
plt.yticks([])
plt.xticks(rotation=-45)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Sofía'),
#   Text(1, 0, 'Luis'),
#   Text(2, 0, 'Pedro'),
#   Text(3, 0, 'Carmen'),
#   Text(4, 0, 'Ana')])

# %% [markdown]
# 10. Prueba a hacer el gráfico con las barras en horizontal.

# %%
plt.figure(figsize=(5,3))
plt.barh(s_alturas.index, s_alturas.values, color="#0bb878")
plt.xlabel("Alturas (cm)")
plt.ylabel("Personas")
plt.title("Comparación de alturas")
# plt.yticks(np.arange(150,200,10));
# plt.yticks([])
# plt.xticks(rotation=-45)
# Out:
# Text(0.5, 1.0, 'Comparación de alturas')

# %% [markdown]
# 11. Prueba a invertir los ejes con ax.invert_axis()
# Necesitarás tener los ejes disponibles fuera de la figura

# %%
fig, ax = plt.subplots()
plt.barh(s_alturas.index, s_alturas.values, color="#0bb878")
ax.invert_xaxis()
ax.invert_yaxis()

# %% [markdown]
# 12. En el último gráfico, cambia el estilo a 'dark_background'

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("dark_background")
fig, ax = plt.subplots()
plt.barh(s_alturas.index, s_alturas.values, color="#0bb878")
ax.invert_xaxis()
ax.invert_yaxis()

# %% [markdown]
# 13. Vamos a introducir pandas. Crea un DataFrame con las columnas "Year" de valores 2015, 2016, 2017, 2018, 2019 y la columna "Sold_items_A" de valores 1000, 3500, 4000, 5500, 7000

# %%
df_13 = pd.DataFrame({"year": [2015, 2016, 2017, 2018, 2019],
                      "Sold_items_A": [1000, 3500, 4000, 5500, 7000]})
df_13
# Out:
#    year  Sold_items_A
# 0  2015          1000
# 1  2016          3500
# 2  2017          4000
# 3  2018          5500
# 4  2019          7000

# %%
df_13.dtypes
# Out:
# year            int64
# Sold_items_A    int64
# dtype: object

# %% [markdown]
# 14. Ahora pintamos un gráfico de línea con las ventas respecto al año. Pon un título y etiquetas en los ejes.
# Cambia el estilo a 'seaborn-white'. La línea debe ser con rayas y verde.

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("seaborn-v0_8-white")

# %%
df_13
# Out:
#    year  Sold_items_A
# 0  2015          1000
# 1  2016          3500
# 2  2017          4000
# 3  2018          5500
# 4  2019          7000

# %%
df_13.set_index("year")
# Out:
#       Sold_items_A
# year
# 2015          1000
# 2016          3500
# 2017          4000
# 2018          5500
# 2019          7000

# %%
df_13.set_index("year").plot()
# Out:
# <Axes: xlabel='year'>

# %%
plt.plot(df_13['year'], df_13['Sold_items_A'], '--g')

# %%
plt.plot(df_13['year'], df_13['Sold_items_A'], '--g')
plt.xticks(df_13['year'])
plt.xlabel("Año")
plt.ylabel("Ventas A (unidades)")
plt.title("Evolución anual de las ventas")
# Out:
# Text(0.5, 1.0, 'Evolución anual de las ventas')

# %% [markdown]
# 15. Otro departamento B ha vendido en esos años 2000, 3100, 5000, 4000, 6000 unidades. Incluye esa columna en el DataFrame y pinta en la misma gráfica las dos líneas. B es una línea punteada y roja. Muestra una leyenda abajo a la derecha.

# %%
df_13 = pd.DataFrame({"year": [2015, 2016, 2017, 2018, 2019],
                      "Sold_items_A": [1000, 3500, 4000, 5500, 7000],
                      "Sold_items_B": [2000, 3100, 5000, 4000, 6000]})
df_13
# Out:
#    year  Sold_items_A  Sold_items_B
# 0  2015          1000          2000
# 1  2016          3500          3100
# 2  2017          4000          5000
# 3  2018          5500          4000
# 4  2019          7000          6000

# %%
plt.plot(df_13['year'], df_13['Sold_items_A'], '--g', label="Departamento A")
plt.plot(df_13['year'], df_13['Sold_items_B'], ':r', label="Departamento B")
plt.xticks(df_13['year'])
plt.xlabel("Año")
plt.ylabel("Ventas (unidades)")
plt.title("Evolución anual de las ventas")
plt.legend(loc="lower right")

# %% [markdown]
# 16. Haz un scatter del departamento A usando __solo el DataFrame__.
# Pista: el propio DataFrame tiene un método plot.
# df.plot('columna X', 'columna Y', 'kind' = 'scatter)

# %%
df_13.plot("year", "Sold_items_A", kind="scatter")
plt.xticks(df_13['year'])
# Out:
# ([<matplotlib.axis.XTick at 0x23b8e054e90>,
#   <matplotlib.axis.XTick at 0x23b8e018410>,
#   <matplotlib.axis.XTick at 0x23b8e07dcd0>,
#   <matplotlib.axis.XTick at 0x23b8e07fe10>,
#   <matplotlib.axis.XTick at 0x23b8e086150>],
#  [Text(2015, 0, '2015'),
#   Text(2016, 0, '2016'),
#   Text(2017, 0, '2017'),
#   Text(2018, 0, '2018'),
#   Text(2019, 0, '2019')])

# %% [markdown]
# 17. Prueba a cambiar kind a 'pie'

# %%
df_13.set_index("year").plot("year", "Sold_items_A", kind="pie")
# Out:
# <Axes: ylabel='Sold_items_A'>

# %% [markdown]
# 18. Prueba a quitar la leyenda incluyendo legend igual a False, añade labels y quita la etiqueta en Y

# %%
df_13.plot("year", "Sold_items_A", kind="pie", legend=False, labels=df_13['year'], ylabel="", title="Porcentaje de ventas anual A", autopct="%1.1f%%", explode=(0,0.1,0,0,0.1))
# Out:
# <Axes: title={'center': 'Porcentaje de ventas anual A'}>

# %% [markdown]
# 19. Vamos a pintar un histograma de unas alturas generadas aleatoriamente. Crea 300 alturas entre 150 y 190 cm.

# %% [markdown]
# Pista: https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html

# %%
alturas_random = np.random.randint(150, 190, 300)
alturas_random = pd.Series(alturas_random)
alturas_random
# Out:
# 0      176
# 1      172
# 2      178
# 3      183
# 4      175
#       ...
# 295    156
# 296    155
# 297    176
# 298    171
# 299    166
# Length: 300, dtype: int32

# %%
alturas_random.plot(kind="hist", bins=30)
# Out:
# <Axes: ylabel='Frequency'>
