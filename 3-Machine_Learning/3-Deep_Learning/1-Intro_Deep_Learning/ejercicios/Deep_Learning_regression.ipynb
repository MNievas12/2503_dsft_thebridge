# %% [markdown]
# # Regresion Basica: Predecir eficiencia de gasolina

# %% [markdown]
# Este libro usa el set de datos clasico [Auto MPG](https://archive.ics.uci.edu/ml/datasets/auto+mpg) y construye un modelo para predecir el consumo de vehiculos de 1970 y 1980. Para hacer esto proveeremos el modelo con una descripcion de muchos automoviles de ese periodo. Esta descripcion incluye atributos como: Cilindros, desplazamiento, potencia y peso.
#
# El objetivo de este ejercicio es predecir el target miles per galon (MPG), que vendría a representar las millas por galón de combustible.
#
# Este ejemplo usa el API `tf.keras` , revise [Esta Guia](https://www.tensorflow.org/guide/keras) para obtener mas detalles.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow import keras

# %% [markdown]
# ## El set de Datos de MPG
#
# El set de datos esta disponible de el siguiente repositorio [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/).

# %% [markdown]
# ### Obtenga los datos
# Primero descargue el set de datos.
# keras.utils.get_file("auto-mpg.data", "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data")

# %%
dataset = keras.utils.get_file("auto-mpg.data", "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data")
dataset
# Out:
# 'C:\\Users\\Miguel Angel\\.keras\\datasets\\auto-mpg.data'

# %% [markdown]
# Importelo usando pandas.

# %%
df = pd.read_csv(dataset, names=['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight', 'Acceleration', 'Model_year', 'Origin', 'Car_name'], delim_whitespace=True)
df
# Out:
#       MPG  Cylinders  Displacement Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0      130.0  3504.0          12.0
# 1    15.0          8         350.0      165.0  3693.0          11.5
# 2    18.0          8         318.0      150.0  3436.0          11.0
# 3    16.0          8         304.0      150.0  3433.0          12.0
# 4    17.0          8         302.0      140.0  3449.0          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      Model_year  Origin                   Car_name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# ### Limpia los datos
#
# Trata los missings y variables categóricas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MPG           398 non-null    float64
#  1   Cylinders     398 non-null    int64
#  2   Displacement  398 non-null    float64
#  3   Horsepower    398 non-null    object
#  4   Weight        398 non-null    float64
#  5   Acceleration  398 non-null    float64
#  6   Model_year    398 non-null    int64
#  7   Origin        398 non-null    int64
#  8   Car_name      398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df.describe()
# Out:
#               MPG   Cylinders  Displacement       Weight  Acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        Model_year      Origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df['Horsepower'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df['Horsepower'].astype(float)
#
# File c:\Users\Miguel Angel\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File c:\Users\Miguel Angel\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File c:\Users\Miguel Angel\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File c:\Users\Miguel Angel\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File c:\Users\Miguel Angel\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File c:\Users\Miguel Angel\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\Miguel Angel\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '?'

# %%
df[df['Horsepower']=="?"]
# Out:
#       MPG  Cylinders  Displacement Horsepower  Weight  Acceleration  \
# 32   25.0          4          98.0          ?  2046.0          19.0
# 126  21.0          6         200.0          ?  2875.0          17.0
# 330  40.9          4          85.0          ?  1835.0          17.3
# 336  23.6          4         140.0          ?  2905.0          14.3
# 354  34.5          4         100.0          ?  2320.0          15.8
# 374  23.0          4         151.0          ?  3035.0          20.5
#
#      Model_year  Origin              Car_name
# 32           71       1            ford pinto
# 126          74       1         ford maverick
# 330          80       2  renault lecar deluxe
# 336          80       1    ford mustang cobra
# 354          81       2           renault 18i
# 374          82       1        amc concord dl

# %%
df['Horsepower'] = np.where(df['Horsepower'] == '?', np.nan, df['Horsepower'])
df['Horsepower'] = df['Horsepower'].astype(float)
df.describe()
# Out:
#               MPG   Cylinders  Displacement  Horsepower       Weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        Acceleration  Model_year      Origin
# count    398.000000  398.000000  398.000000
# mean      15.568090   76.010050    1.572864
# std        2.757689    3.697627    0.802055
# min        8.000000   70.000000    1.000000
# 25%       13.825000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# 75%       17.175000   79.000000    2.000000
# max       24.800000   82.000000    3.000000

# %%
df['Horsepower'].fillna(df['Horsepower'].mean(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MPG           398 non-null    float64
#  1   Cylinders     398 non-null    int64
#  2   Displacement  398 non-null    float64
#  3   Horsepower    398 non-null    float64
#  4   Weight        398 non-null    float64
#  5   Acceleration  398 non-null    float64
#  6   Model_year    398 non-null    int64
#  7   Origin        398 non-null    int64
#  8   Car_name      398 non-null    object
# dtypes: float64(5), int64(3), object(1)
# memory usage: 28.1+ KB

# %%
df['Origin'].value_counts()
# Out:
# 1    249
# 3     79
# 2     70
# Name: Origin, dtype: int64

# %%
df[df['Origin']==3]
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 14   24.0          4         113.0        95.0  2372.0          15.0
# 18   27.0          4          97.0        88.0  2130.0          14.5
# 29   27.0          4          97.0        88.0  2130.0          14.5
# 31   25.0          4         113.0        95.0  2228.0          14.0
# 53   31.0          4          71.0        65.0  1773.0          19.0
# ..    ...        ...           ...         ...     ...           ...
# 382  34.0          4         108.0        70.0  2245.0          16.9
# 383  38.0          4          91.0        67.0  1965.0          15.0
# 384  32.0          4          91.0        67.0  1965.0          15.7
# 385  38.0          4          91.0        67.0  1995.0          16.2
# 390  32.0          4         144.0        96.0  2665.0          13.9
#
#      Model_year  Origin               Car_name
# 14           70       3  toyota corona mark ii
# 18           70       3           datsun pl510
# 29           71       3           datsun pl510
# 31           71       3          toyota corona
# 53           71       3    toyota corolla 1200
# ..          ...     ...                    ...
# 382          82       3         toyota corolla
# 383          82       3            honda civic
# 384          82       3     honda civic (auto)
# 385          82       3          datsun 310 gx
# 390          82       3       toyota celica gt
#
# [79 rows x 9 columns]

# %%
df.groupby('Origin')['MPG'].mean()
# Out:
# Origin
# 1    20.083534
# 2    27.891429
# 3    30.450633
# Name: MPG, dtype: float64

# %%
marcas = df['Car_name'].str.split(expand=True, n=1)[0]
marcas
# Out:
# 0      chevrolet
# 1          buick
# 2       plymouth
# 3            amc
# 4           ford
#          ...
# 393         ford
# 394           vw
# 395        dodge
# 396         ford
# 397        chevy
# Name: 0, Length: 398, dtype: object

# %%
marcas.value_counts()
# Out:
# ford             51
# chevrolet        43
# plymouth         31
# amc              28
# dodge            28
# toyota           25
# datsun           23
# buick            17
# pontiac          16
# volkswagen       15
# honda            13
# mercury          11
# mazda            10
# oldsmobile       10
# fiat              8
# peugeot           8
# audi              7
# chrysler          6
# vw                6
# volvo             6
# renault           5
# saab              4
# subaru            4
# opel              4
# chevy             3
# bmw               2
# cadillac          2
# maxda             2
# mercedes-benz     2
# triumph           1
# vokswagen         1
# mercedes          1
# hi                1
# capri             1
# chevroelt         1
# toyouta           1
# nissan            1
# Name: 0, dtype: int64

# %%
df['Marca'] = marcas.copy()
df.groupby("Marca")['MPG'].agg(['count','mean']).sort_values('mean', ascending=False)
# Out:
#                count       mean
# Marca
# vw                 6  39.016667
# nissan             1  36.000000
# triumph            1  35.000000
# honda             13  33.761538
# renault            5  32.880000
# datsun            23  31.113043
# mazda             10  30.860000
# subaru             4  30.525000
# vokswagen          1  29.800000
# volkswagen        15  29.106667
# fiat               8  28.912500
# toyota            25  28.372000
# audi               7  26.714286
# maxda              2  26.050000
# opel               4  25.750000
# mercedes           1  25.400000
# capri              1  25.000000
# saab               4  23.900000
# bmw                2  23.750000
# peugeot            8  23.687500
# mercedes-benz      2  23.250000
# toyouta            1  23.000000
# dodge             28  22.060714
# plymouth          31  21.703226
# volvo              6  21.116667
# oldsmobile        10  21.100000
# chevrolet         43  20.472093
# pontiac           16  20.012500
# cadillac           2  19.750000
# ford              51  19.694118
# buick             17  19.182353
# mercury           11  19.118182
# amc               28  18.246429
# chevy              3  18.000000
# chrysler           6  17.266667
# chevroelt          1  16.000000
# hi                 1   9.000000

# %% [markdown]
# ### Divide los datos en train y test
#
# Ahora divida el set de datos en un set de entrenamiento y otro de pruebas. 80% para entrenamiento
#
# Usaremos el set de pruebas en la evaluacion final de nuestro modelo.
#
# NOTA: El resultado tienen que ser dos datasets

# %%
df.drop(columns=["Car_name", "Marca"], inplace=True)

# %%
df.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    Model_year  Origin
# 0          70       1
# 1          70       1
# 2          70       1
# 3          70       1
# 4          70       1

# %%
train = df.sample(frac=0.8, random_state=42)
test = df.drop(train.index)

# %%
print(train.shape)
print(test.shape)
# Out:
# (318, 8)
# (80, 8)

# %% [markdown]
# ### Inspecciona los datos
#
# Revise rapidamente la distribucion conjunta del dataset de entrenamiento mediante un grid de gráficos

# %%
sns.pairplot(df)

# %% [markdown]
# Tambien revise las estadisticas generales:

# %%
df.describe()
# Out:
#               MPG   Cylinders  Displacement  Horsepower       Weight  \
# count  398.000000  398.000000    398.000000  398.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.199187   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   76.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   95.000000  2803.500000
# 75%     29.000000    8.000000    262.000000  125.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        Acceleration  Model_year      Origin
# count    398.000000  398.000000  398.000000
# mean      15.568090   76.010050    1.572864
# std        2.757689    3.697627    0.802055
# min        8.000000   70.000000    1.000000
# 25%       13.825000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# 75%       17.175000   79.000000    2.000000
# max       24.800000   82.000000    3.000000

# %%
sns.heatmap(df.corr(), annot=True, vmin=-1, cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# ### Separa las features del target
#
# Separe el target de las features.

# %%
X_train = train.drop(columns="MPG")
X_test = test.drop(columns="MPG")
y_train = train['MPG']
y_test = test['MPG']

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (318, 7)
# (80, 7)
# (318,)
# (80,)

# %% [markdown]
# ### Estandariza los datos

# %% [markdown]
# Es una buena práctica estandarizar funciones que utilizan diferentes escalas y rangos. Aunque el modelo podría converger sin estandarizar, dificulta el entrenamiento y hace que el modelo resultante dependa de la elección de las unidades utilizadas en la entrada.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scal = scaler.fit_transform(X_train)
X_test_scal = scaler.transform(X_test)

# %% [markdown]
# Estos datos estandarizados es lo que usaremos para entrenar el modelo.

# %% [markdown]
# ## El modelo

# %% [markdown]
# ### Construye el modelo
#
# Construyamos nuestro modelo. Aquí, utilizaremos un modelo `secuencial` con dos capas ocultas densamente conectadas y una capa de salida que devuelve un único valor continuo.
#
# Por tanto, tendrá tres capas. Una de entrada con activación relu. Otra hidden layer con activación relu y la de salida de regresión, que se compondrá de una única neurona. Pon las neuronas que consideres para las dos primeras capas.
#
# Para el compile utiliza un loss='mse'.
#
# optimizer = `tf.keras.optimizers.RMSprop(0.001)`
#
# Y en metrics añade en una lista el `mae` y `mse`.

# %%
X_train.shape[1:]
# Out:
# (7,)

# %%
model = keras.Sequential([
    keras.layers.Dense(64, activation="relu", input_shape=X_train.shape[1:]),
    keras.layers.Dense(1, activation="relu")
])

model.compile(
    loss = "mse",
    optimizer = keras.optimizers.RMSprop(0.001),
    metrics = ['mae']
)

# %% [markdown]
# ### Inspeccione el modelo
#
# Use el método `.summary` para imprimir una descripción simple del modelo

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 64)                512
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 577 (2.25 KB)
# Trainable params: 577 (2.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
7*64 + 64
# Out:
# 512

# %% [markdown]
# ### Entrenar el modelo
#
# Entrene el modelo para 1000 epochs y guarda los resultados del entrenamiento en una variable llamada `history`.
# Emplea en el entrenamiento un 20% de los datos para validación, mediante el argumento `validation_split`.
#
# NOTA: recuerda usar los datos normalizados.

# %%
early_stopping = keras.callbacks.EarlyStopping(patience=10)

# %%
X_train_scal.shape[0]*0.8/32
# Out:
# 7.95

# %%
history = model.fit(
    X_train_scal,
    y_train,
    batch_size=32,
    epochs=1000,
    validation_split=0.2,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/1000
# WARNING:tensorflow:From c:\Users\Miguel Angel\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Miguel Angel\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 8/8 [==============================] - 4s 94ms/step - loss: 615.7048 - mae: 23.5728 - val_loss: 544.7328 - val_mae: 21.8480
# Epoch 2/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 601.7167 - mae: 23.2655 - val_loss: 533.1037 - val_mae: 21.5693
# Epoch 3/1000
# 8/8 [==============================] - 0s 15ms/step - loss: 589.6072 - mae: 23.0014 - val_loss: 522.5154 - val_mae: 21.3145
# Epoch 4/1000
# 8/8 [==============================] - 0s 14ms/step - loss: 578.1938 - mae: 22.7516 - val_loss: 512.3094 - val_mae: 21.0636
# Epoch 5/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 567.0926 - mae: 22.5024 - val_loss: 502.1807 - val_mae: 20.8110
# Epoch 6/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 556.0186 - mae: 22.2532 - val_loss: 491.9152 - val_mae: 20.5516
# Epoch 7/1000
# 8/8 [==============================] - 0s 17ms/step - loss: 544.6473 - mae: 21.9930 - val_loss: 481.4019 - val_mae: 20.2809
# Epoch 8/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 533.0634 - mae: 21.7253 - val_loss: 470.8045 - val_mae: 20.0048
# Epoch 9/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 521.2557 - mae: 21.4467 - val_loss: 459.9729 - val_mae: 19.7200
# Epoch 10/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 509.1475 - mae: 21.1611 - val_loss: 448.9297 - val_mae: 19.4231
# Epoch 11/1000
# 8/8 [==============================] - 0s 14ms/step - loss: 496.7023 - mae: 20.8597 - val_loss: 437.6874 - val_mae: 19.1192
# Epoch 12/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 483.7886 - mae: 20.5466 - val_loss: 426.1357 - val_mae: 18.8077
# Epoch 13/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 470.5261 - mae: 20.2258 - val_loss: 414.3535 - val_mae: 18.4826
# Epoch 14/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 457.0628 - mae: 19.8926 - val_loss: 402.4755 - val_mae: 18.1483
# Epoch 15/1000
# 8/8 [==============================] - 0s 17ms/step - loss: 443.6036 - mae: 19.5525 - val_loss: 390.6028 - val_mae: 17.8058
# Epoch 16/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 429.7610 - mae: 19.1978 - val_loss: 378.3419 - val_mae: 17.4523
# Epoch 17/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 415.5712 - mae: 18.8246 - val_loss: 366.0558 - val_mae: 17.0864
# Epoch 18/1000
# 8/8 [==============================] - 0s 17ms/step - loss: 401.1711 - mae: 18.4482 - val_loss: 353.5472 - val_mae: 16.7072
# Epoch 19/1000
# 8/8 [==============================] - 0s 24ms/step - loss: 386.8369 - mae: 18.0509 - val_loss: 341.3454 - val_mae: 16.3272
# Epoch 20/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 372.4714 - mae: 17.6536 - val_loss: 329.0507 - val_mae: 15.9588
# Epoch 21/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 358.0681 - mae: 17.2560 - val_loss: 316.6123 - val_mae: 15.5819
# Epoch 22/1000
# 8/8 [==============================] - 0s 33ms/step - loss: 343.4633 - mae: 16.8531 - val_loss: 304.2728 - val_mae: 15.2044
# Epoch 23/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 328.8218 - mae: 16.4477 - val_loss: 291.8802 - val_mae: 14.8642
# Epoch 24/1000
# 8/8 [==============================] - 0s 24ms/step - loss: 314.0460 - mae: 16.0502 - val_loss: 279.3568 - val_mae: 14.5126
# Epoch 25/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 299.2303 - mae: 15.6477 - val_loss: 266.8272 - val_mae: 14.1507
# Epoch 26/1000
# 8/8 [==============================] - 0s 21ms/step - loss: 284.4303 - mae: 15.2374 - val_loss: 254.4323 - val_mae: 13.7860
# Epoch 27/1000
# 8/8 [==============================] - 0s 28ms/step - loss: 269.8674 - mae: 14.8315 - val_loss: 242.0972 - val_mae: 13.4146
# Epoch 28/1000
# 8/8 [==============================] - 0s 13ms/step - loss: 255.4371 - mae: 14.4159 - val_loss: 230.1129 - val_mae: 13.0432
# Epoch 29/1000
# 8/8 [==============================] - 0s 12ms/step - loss:
1000
# 8/8 [==============================] - 0s 12ms/step - loss: 9.3599 - mae: 2.1769 - val_loss: 12.4310 - val_mae: 2.4077
# Epoch 94/1000
# 8/8 [==============================] - 0s 13ms/step - loss: 9.2291 - mae: 2.1600 - val_loss: 12.2966 - val_mae: 2.4004
# Epoch 95/1000
# 8/8 [==============================] - 0s 14ms/step - loss: 9.0975 - mae: 2.1490 - val_loss: 12.3374 - val_mae: 2.4051
# Epoch 96/1000
# 8/8 [==============================] - 0s 13ms/step - loss: 8.9595 - mae: 2.1302 - val_loss: 12.3709 - val_mae: 2.3777
# Epoch 97/1000
# 8/8 [==============================] - 0s 13ms/step - loss: 8.8871 - mae: 2.0966 - val_loss: 12.2042 - val_mae: 2.3611
# Epoch 98/1000
# 8/8 [==============================] - 0s 14ms/step - loss: 8.7603 - mae: 2.0962 - val_loss: 12.1772 - val_mae: 2.3531
# Epoch 99/1000
# 8/8 [==============================] - 0s 14ms/step - loss: 8.6776 - mae: 2.0633 - val_loss: 12.0061 - val_mae: 2.3438
# Epoch 100/1000
# 8/8 [==============================] - 0s 12ms/step - loss: 8.5972 - mae: 2.0600 - val_loss: 11.9880 - val_mae: 2.3499
# Epoch 101/1000
# 8/8 [==============================] - 0s 14ms/step - loss: 8.5097 - mae: 2.0644 - val_loss: 12.0691 - val_mae: 2.3449
# Epoch 102/1000
# 8/8 [==============================] - 0s 24ms/step - loss: 8.3966 - mae: 2.0320 - val_loss: 12.0023 - val_mae: 2.3279
# Epoch 103/1000
# 8/8 [==============================] - 0s 12ms/step - loss: 8.3555 - mae: 2.0149 - val_loss: 11.9625 - val_mae: 2.3314
# Epoch 104/1000
# 8/8 [==============================] - 0s 15ms/step - loss: 8.1988 - mae: 2.0116 - val_loss: 12.0448 - val_mae: 2.3156
# Epoch 105/1000
# 8/8 [==============================] - 0s 13ms/step - loss: 8.1695 - mae: 1.9966 - val_loss: 12.0394 - val_mae: 2.3110
# Epoch 106/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 8.0727 - mae: 1.9793 - val_loss: 11.9400 - val_mae: 2.2916
# Epoch 107/1000
# 8/8 [==============================] - 0s 15ms/step - loss: 8.0202 - mae: 1.9782 - val_loss: 11.9178 - val_mae: 2.2923
# Epoch 108/1000
# 8/8 [==============================] - 0s 13ms/step - loss: 8.0195 - mae: 1.9597 - val_loss: 11.8135 - val_mae: 2.2774
# Epoch 109/1000
# 8/8 [==============================] - 0s 14ms/step - loss: 7.8736 - mae: 1.9531 - val_loss: 11.7195 - val_mae: 2.2641
# Epoch 110/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 7.8541 - mae: 1.9416 - val_loss: 11.6074 - val_mae: 2.2661
# Epoch 111/1000
# 8/8 [==============================] - 0s 15ms/step - loss: 7.7589 - mae: 1.9431 - val_loss: 11.7265 - val_mae: 2.2626
# Epoch 112/1000
# 8/8 [==============================] - 0s 14ms/step - loss: 7.7091 - mae: 1.9205 - val_loss: 11.5751 - val_mae: 2.2472
# Epoch 113/1000
# 8/8 [==============================] - 0s 13ms/step - loss: 7.6690 - mae: 1.9256 - val_loss: 11.6972 - val_mae: 2.2523
# Epoch 114/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 7.6256 - mae: 1.9029 - val_loss: 11.5775 - val_mae: 2.2358
# Epoch 115/1000
# 8/8 [==============================] - 0s 14ms/step - loss: 7.5867 - mae: 1.9126 - val_loss: 11.6342 - val_mae: 2.2380
# Epoch 116/1000
# 8/8 [==============================] - 0s 14ms/step - loss: 7.4679 - mae: 1.8849 - val_loss: 11.5928 - val_mae: 2.2475
# Epoch 117/1000
# 8/8 [==============================] - 0s 14ms/step - loss: 7.4609 - mae: 1.8672 - val_loss: 11.3868 - val_mae: 2.2202
# Epoch 118/1000
# 8/8 [==============================] - 0s 17ms/step - loss: 7.4322 - mae: 1.8778 - val_loss: 11.3312 - val_mae: 2.2236
# Epoch 119/1000
# 8/8 [==============================] - 0s 21ms/step - loss: 7.3655 - mae: 1.8821 - val_loss: 11.3330 - val_mae: 2.2199
# Epoch 120/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 7.3292 - mae: 1.8665 - val_loss: 11.2710 - val_mae: 2.2101
# Epoch 121/1000
# 8/8 [==============================] - 0s 14ms/step - loss: 7.3145 - mae: 1.8630 - val_loss: 11.3608 - val_mae: 2.2238
# Epoch 122/1000
# 8/8 [==============================] - 0s 14ms/step - loss: 7.1967 - mae: 1.8482 - val_loss: 11.4214 - val_mae: 2.1966
# Epoch 123/1000
# 8/8 [==============================] - 0s 27ms/step - loss: 7.2519 - mae: 1.8469 - val_loss: 11.3761 - val_mae: 2.2113
# Epoch 124/1000
# 8/8 [==============================] - 0s 14ms/step - loss: 7.1683 - mae: 1.8495 - val_loss: 11.4795 - val_mae: 2.2115
# Epoch 125/1000
# 8/8 [==============================] - 0s 13ms/step - loss: 7.1421 - mae: 1.8162 - val_loss: 11.3904 - val_mae: 2.1898
# Epoch 126/1000
# 8/8 [==============================] - 0s 14ms/step - loss: 7.0900 - mae: 1.8350 - val_loss: 11.5680 - val_mae: 2.2158
# Epoch 127/1000
# 8/8 [==============================] - 0s 15ms/step - loss: 7.0412 - mae: 1.8086 - val_loss: 11.4070 - val_mae: 2.2144
# Epoch 128/1000
# 8/8 [==============================] - 0s 17ms/step - loss: 7.0476 - mae: 1.8305 - val_loss: 11.4398 - val_mae: 2.2045
# Epoch 129/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 6.9971 - mae: 1.8051 - val_loss: 11.3721 - val_mae: 2.1777
# Epoch 130/1000
# 8/8 [==============================] - 0s 13ms/step - loss: 7.0001 - mae: 1.8173 - val_loss: 11.3819 - val_mae: 2.1759

# %% [markdown]
# Visualice el progreso de entrenamiento del modelo usando las estadísticas almacenadas en el objeto `history`.

# %%
history.history
# Out:
# {'loss': [615.704833984375,
#   601.7166748046875,
#   589.607177734375,
#   578.1937866210938,
#   567.0925903320312,
#   556.0185546875,
#   544.6472778320312,
#   533.0633544921875,
#   521.2557373046875,
#   509.1474914550781,
#   496.7023010253906,
#   483.78863525390625,
#   470.5260925292969,
#   457.0628356933594,
#   443.60357666015625,
#   429.760986328125,
#   415.5711975097656,
#   401.1710510253906,
#   386.8369445800781,
#   372.47137451171875,
#   358.0680847167969,
#   343.4632873535156,
#   328.82177734375,
#   314.0460205078125,
#   299.2303161621094,
#   284.4302673339844,
#   269.867431640625,
#   255.43707275390625,
#   241.20860290527344,
#   227.1837158203125,
#   213.1515655517578,
#   199.51365661621094,
#   186.3465576171875,
#   173.48191833496094,
#   160.91796875,
#   148.6488494873047,
#   136.96847534179688,
#   125.9923095703125,
#   115.5005874633789,
#   105.53712463378906,
#   96.41915130615234,
#   87.9587173461914,
#   80.2432632446289,
#   73.4132308959961,
#   67.48544311523438,
#   62.27957534790039,
#   57.77208709716797,
#   53.90384292602539,
#   50.5764274597168,
#   47.65019226074219,
#   45.287078857421875,
#   43.12850570678711,
#   41.14273452758789,
#   39.32196044921875,
#   37.585777282714844,
#   35.87220764160156,
#   34.282020568847656,
#   32.63612747192383,
#   31.15227508544922,
#   29.62900733947754,
#   28.204713821411133,
#   26.882015228271484,
#   25.555683135986328,
#   24.410411834716797,
#   23.143274307250977,
#   22.083282470703125,
#   21.10814666748047,
#   20.110584259033203,
#   19.18077278137207,
#   18.34423828125,
#   17.464540481567383,
#   16.719873428344727,
#   16.07457160949707,
#   15.41574764251709,
#   14.854923248291016,
#   14.243741035461426,
#   13.708127975463867,
#   13.237324714660645,
#   12.82123851776123,
#   12.377601623535156,
#   12.059877395629883,
#   11.675951957702637,
#   11.365304946899414,
#   11.08179759979248,
#   10.81079387664795,
#   10.580153465270996,
#   10.33374309539795,
#   10.16060733795166,
#   9.978188514709473,
#   9.869950294494629,
#   9.645356178283691,
#   9.511321067810059,
#   9.359861373901367,
#   9.229065895080566,
#   9.097498893737793,
#   8.959527015686035,
#   8.887107849121094,
#   8.76032543182373,
#   8.677584648132324,
#   8.597246170043945,
#   8.509681701660156,
#   8.396581649780273,
#   8.355478286743164,
#   8.198796272277832,
#   8.169540405273438,
#   8.072731018066406,
#   8.02021312713623,
#   8.019484519958496,
#   7.873566150665283,
#   7.854138374328613,
# %%
pd.DataFrame(history.history)[['loss', 'val_loss']].plot()
# Out:
# <Axes: >

# %%
pd.DataFrame(history.history)[['loss', 'val_loss']].plot()
plt.ylim(0,30)
plt.xlim(60,130)
# Out:
# (60.0, 130.0)

# %% [markdown]
# ¿Alguna conclusión respecto a este gráfico?

# %% [markdown]
# Earlystopping me ha ayudado a detener el entrenamiento para no caer en overfitting, también para ahorrar recursos innecesarios.

# %% [markdown]
# Observamos que si le damos muchas epochs al entrenamiento tiende a un overfitting, siendo el error en validación cada vez más alto. Sería interesante utilizar un número aprox de 30 epochs

# %% [markdown]
# Añade un early stopping al modelo. Pon el argumento `callbacks=[keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)]` dentro del fit().
#
# Visualiza el progreso de entrenamiento.

# %% [markdown]
# Interpreta el gráfico

# %% [markdown]
# Veamos qué tan bien generaliza el modelo al usar el conjunto de **test**. Esto nos dice qué tan bien podemos esperar que el modelo prediga cuándo lo usamos en el mundo real. Utiliza el método `evaluate` con los datos de test normalizados y sus labels.
#
# Con el método evaluate devolverá tres valores: loss, mae y mse.

# %%
model.evaluate(X_test_scal, y_test)
# Out:
# 3/3 [==============================] - 0s 12ms/step - loss: 8.8550 - mae: 2.1508
# [8.854994773864746, 2.1508452892303467]

# %% [markdown]
# Ahora prueba el modelo. Coge 10 ejemplos de test y llama a` model.predict`.

# %%
model.predict(X_test_scal[:10])
# Out:
# 1/1 [==============================] - 1s 507ms/step
# array([[15.223266],
#        [14.71396 ],
#        [21.13577 ],
#        [22.67998 ],
#        [16.146788],
#        [12.508292],
#        [18.694405],
#        [24.826122],
#        [23.94035 ],
#        [26.220102]], dtype=float32)

# %% [markdown]
# ### Haz Predicciones
#
# Dibuja en un scatter plot las predicciones de test vs sus true labels.

# %%
y_pred = model.predict(X_test_scal)
y_pred
# Out:
# 3/3 [==============================] - 0s 4ms/step
# array([[15.223266],
#        [14.71396 ],
#        [21.13577 ],
#        [22.67998 ],
#        [16.146788],
#        [12.508292],
#        [18.694405],
#        [24.826122],
#        [23.94035 ],
#        [26.220102],
#        [30.472433],
#        [30.644533],
#        [25.550575],
#        [28.09575 ],
#        [23.512941],
#        [15.359184],
#        [15.260139],
#        [14.369243],
#        [18.55196 ],
#        [28.819965],
#        [12.680451],
#        [12.75417 ],
#        [17.19441 ],
#        [24.745214],
#        [15.239419],
#        [24.574097],
#        [28.387486],
#        [16.042757],
#        [15.651225],
#        [19.07533 ],
#        [19.286089],
#        [22.188105],
#        [15.690664],
#        [15.287919],
#        [17.190472],
#        [15.184684],
#        [19.291794],
#        [16.105755],
#        [30.30154 ],
#        [19.43021 ],
#        [14.031194],
#        [16.515173],
#        [29.543682],
#        [30.788616],
#        [21.584564],
#        [28.562534],
#        [18.36682 ],
#        [17.839981],
#        [20.136696],
#        [22.35726 ],
#        [15.921817],
#        [20.539577],
#        [30.77493 ],
#        [26.927856],
#        [27.9211  ],
#        [22.515364],
#        [33.307964],
#        [32.986607],
#        [35.178753],
#        [27.334465],
#        [27.876024],
#        [32.59331 ],
#        [26.14156 ],
#        [24.539345],
#        [31.14031 ],
#        [27.255909],
#        [31.407104],
#        [27.975254],
#        [38.629612],
#        [35.987232],
#        [36.718933],
#        [27.14071 ],
#        [24.989372],
#        [21.07788 ],
#        [28.348118],
#        [35.494755],
#        [29.165506],
#        [32.55783 ],
#        [33.824562],
#        [30.566875]], dtype=float32)

# %%
plt.scatter(y_test,y_pred)

# %% [markdown]
# Parece que nuestro modelo predice razonablemente bien. Echemos un vistazo a la distribución de errores.
#
# Representa los residuos en un histograma

# %%
error = y_pred.reshape(-1) - y_test
plt.hist(error);

# %% [markdown]
# No es del todo gaussiano, pero podríamos esperar eso porque el número de muestras es muy pequeño.

# %% [markdown]
# Guarda tu modelo en un archivo.

# %%
model.save("final_model.keras")

# %%
imported_model = keras.models.load_model("final_model.keras")
imported_model
