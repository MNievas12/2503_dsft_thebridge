# %% [markdown]
# # Textacy & Spacy
# Librerias de procesado de NLP

# %%
# usamos python 3.10 por compatibilidad !!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
#!pip install --user  --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (25.1.1)

# %%
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (3.8.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy) (0.15.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.2.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.11.4)
# Requirement already satisfied: jinja2 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy) (57.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\alberto romero\appdata\roaming\python\python310\site-packages (from spacy) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\alberto romero\appdata\roaming\python\python310\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.4.26)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\alberto romero\appdata\roaming\python\python310\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.0.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: wrapt in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\alberto romero\appdata\roaming\python\python310\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from jinja2->spacy) (3.0.2)
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------- ----------------------------- 3.4/12.8 MB 20.2 MB/s eta 0:00:01
#      ------------------------------ --------- 9.7/12.8 MB 25.2 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 23.0 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# %pip install textacy
# Out:
# Requirement already satisfied: textacy in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (0.13.0)
# Requirement already satisfied: cachetools>=4.0.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy) (5.5.2)
# Requirement already satisfied: catalogue~=2.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy) (2.0.10)
# Requirement already satisfied: cytoolz>=0.10.1 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy) (1.0.1)
# Requirement already satisfied: floret~=0.10.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy) (0.10.5)
# Requirement already satisfied: jellyfish>=0.8.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy) (1.2.0)
# Requirement already satisfied: joblib>=0.13.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy) (1.5.0)
# Requirement already satisfied: networkx>=2.7 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy) (3.4.2)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy) (2.2.5)
# Requirement already satisfied: pyphen>=0.10.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy) (0.17.2)
# Requirement already satisfied: requests>=2.10.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy) (2.32.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy) (1.15.2)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy) (1.6.1)
# Requirement already satisfied: spacy~=3.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy) (3.8.5)
# Requirement already satisfied: tqdm>=4.19.6 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy) (4.67.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy~=3.0->textacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy~=3.0->textacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy~=3.0->textacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy~=3.0->textacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy~=3.0->textacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy~=3.0->textacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy~=3.0->textacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy~=3.0->textacy) (2.5.1)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy~=3.0->textacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy~=3.0->textacy) (0.15.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy~=3.0->textacy) (2.11.4)
# Requirement already satisfied: jinja2 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy~=3.0->textacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy~=3.0->textacy) (57.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\alberto romero\appdata\roaming\python\python310\site-packages (from spacy~=3.0->textacy) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy~=3.0->textacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy~=3.0->textacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy~=3.0->textacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy~=3.0->textacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\alberto romero\appdata\roaming\python\python310\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy~=3.0->textacy) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy~=3.0->textacy) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.10.0->textacy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.10.0->textacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.10.0->textacy) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.10.0->textacy) (2025.4.26)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy~=3.0->textacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy~=3.0->textacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\alberto romero\appdata\roaming\python\python310\site-packages (from tqdm>=4.19.6->textacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy~=3.0->textacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy~=3.0->textacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy~=3.0->textacy) (14.0.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy~=3.0->textacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy~=3.0->textacy) (7.1.0)
# Requirement already satisfied: wrapt in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy~=3.0->textacy) (1.17.2)
# Requirement already satisfied: toolz>=0.8.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from cytoolz>=0.10.1->textacy) (1.0.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy~=3.0->textacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy~=3.0->textacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\alberto romero\appdata\roaming\python\python310\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy~=3.0->textacy) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy~=3.0->textacy) (0.1.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=1.0->textacy) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from jinja2->spacy~=3.0->textacy) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download en_core_web_lg
# Out:
# Collecting en-core-web-lg==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.8.0/en_core_web_lg-3.8.0-py3-none-any.whl (400.7 MB)
#      ---------------------------------------- 0.0/400.7 MB ? eta -:--:--
#      --------------------------------------- 3.7/400.7 MB 21.8 MB/s eta 0:00:19
#       ------------------------------------- 10.2/400.7 MB 26.6 MB/s eta 0:00:15
#      - ------------------------------------ 15.7/400.7 MB 27.5 MB/s eta 0:00:14
#      -- ----------------------------------- 22.3/400.7 MB 27.6 MB/s eta 0:00:14
#      -- ----------------------------------- 27.5/400.7 MB 26.8 MB/s eta 0:00:14
#      --- ---------------------------------- 33.0/400.7 MB 26.6 MB/s eta 0:00:14
#      --- ---------------------------------- 39.3/400.7 MB 27.2 MB/s eta 0:00:14
#      ---- --------------------------------- 45.4/400.7 MB 27.2 MB/s eta 0:00:14
#      ---- --------------------------------- 51.9/400.7 MB 27.5 MB/s eta 0:00:13
#      ----- -------------------------------- 58.7/400.7 MB 28.1 MB/s eta 0:00:13
#      ------ ------------------------------- 64.5/400.7 MB 28.0 MB/s eta 0:00:13
#      ------ ------------------------------- 70.8/400.7 MB 28.0 MB/s eta 0:00:12
#      ------- ------------------------------ 76.5/400.7 MB 28.1 MB/s eta 0:00:12
#      ------- ------------------------------ 82.6/400.7 MB 28.0 MB/s eta 0:00:12
#      -------- ----------------------------- 87.3/400.7 MB 27.7 MB/s eta 0:00:12
#      -------- ----------------------------- 93.3/400.7 MB 27.8 MB/s eta 0:00:12
#      --------- --------------------------- 100.1/400.7 MB 27.9 MB/s eta 0:00:11
#      --------- --------------------------- 107.2/400.7 MB 28.3 MB/s eta 0:00:11
#      ---------- -------------------------- 113.5/400.7 MB 28.3 MB/s eta 0:00:11
#      ----------- ------------------------- 120.8/400.7 MB 28.5 MB/s eta 0:00:10
#      ----------- ------------------------- 127.4/400.7 MB 28.7 MB/s eta 0:00:10
#      ------------ ------------------------ 133.2/400.7 MB 28.6 MB/s eta 0:00:10
#      ------------ ------------------------ 140.0/400.7 MB 28.8 MB/s eta 0:00:10
#      ------------- ----------------------- 146.3/400.7 MB 28.8 MB/s eta 0:00:09
MB/s eta 0:00:01
#      ------------------------------------  400.6/400.7 MB 28.8 MB/s eta 0:00:01
#      ------------------------------------  400.6/400.7 MB 28.8 MB/s eta 0:00:01
#      ------------------------------------  400.6/400.7 MB 28.8 MB/s eta 0:00:01
#      ------------------------------------- 400.7/400.7 MB 26.7 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
# !python -m spacy download es_core_news_lg
# Out:
# Collecting es-core-news-lg==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_lg-3.8.0/es_core_news_lg-3.8.0-py3-none-any.whl (568.0 MB)
#      ---------------------------------------- 0.0/568.0 MB ? eta -:--:--
#      --------------------------------------- 2.6/568.0 MB 15.1 MB/s eta 0:00:38
#       -------------------------------------- 8.9/568.0 MB 22.2 MB/s eta 0:00:26
#      - ------------------------------------ 15.2/568.0 MB 25.2 MB/s eta 0:00:22
#      - ------------------------------------ 20.4/568.0 MB 25.3 MB/s eta 0:00:22
#      - ------------------------------------ 26.0/568.0 MB 25.3 MB/s eta 0:00:22
#      -- ----------------------------------- 31.2/568.0 MB 25.1 MB/s eta 0:00:22
#      -- ----------------------------------- 39.1/568.0 MB 26.4 MB/s eta 0:00:21
#      --- ---------------------------------- 45.4/568.0 MB 27.0 MB/s eta 0:00:20
#      --- ---------------------------------- 52.4/568.0 MB 27.6 MB/s eta 0:00:19
#      --- ---------------------------------- 59.0/568.0 MB 27.8 MB/s eta 0:00:19
#      ---- --------------------------------- 65.3/568.0 MB 27.9 MB/s eta 0:00:19
#      ---- --------------------------------- 72.4/568.0 MB 28.5 MB/s eta 0:00:18
#      ----- -------------------------------- 78.9/568.0 MB 28.8 MB/s eta 0:00:18
#      ----- -------------------------------- 85.5/568.0 MB 28.7 MB/s eta 0:00:17
#      ------ ------------------------------- 91.2/568.0 MB 28.5 MB/s eta 0:00:17
#      ------ ------------------------------- 99.4/568.0 MB 29.2 MB/s eta 0:00:17
#      ------ ------------------------------ 105.6/568.0 MB 29.2 MB/s eta 0:00:16
#      ------- ----------------------------- 112.5/568.0 MB 29.3 MB/s eta 0:00:16
#      ------- ----------------------------- 119.5/568.0 MB 29.6 MB/s eta 0:00:16
#      -------- ---------------------------- 125.3/568.0 MB 29.3 MB/s eta 0:00:16
#      -------- ---------------------------- 129.5/568.0 MB 28.8 MB/s eta 0:00:16
#      -------- ---------------------------- 134.5/568.0 MB 28.5 MB/s eta 0:00:16
#      --------- --------------------------- 140.2/568.0 MB 28.4 MB/s eta 0:00:16
#      --------- --------------------------- 146.3/568.0 MB 28.4 MB/s eta 0:00:15
#      --------- --------------------------- 152.0/568.0 MB 28.4 MB/s eta 0:00:15
#      ---------- -------------------------- 157.0/568.0 MB 28.2 MB/s eta 0:00:15
#      ---------- -------------------------- 163.8/568.0 MB 28.3 MB/s eta 0:00:15
#      ----------- ------------------------- 170.7/568.0 MB 28.4 MB/s eta 0:00:14
#      ----------- ------------------------- 177.5/568.0 MB 28.5 MB/s eta 0:00:14
#      ----------- ------------------------- 184.0/568.0 MB 28.5 MB/s eta 0:00:14
#      ------------ ------------------------ 190.1/568.0 MB 28.6 MB/s eta 0:00:14
#      ------------ ------------------------ 195.8/568.0 MB 28.6 MB/s eta 0:00:14
#      ------------- ----------------------- 200.5/568.0 MB 28.4 MB/s eta 0:00:13
#      ---------------------------- -------- 444.9/568.0 MB 28.4 MB/s eta 0:00:05
#      ----------------------------- ------- 451.4/568.0 MB 28.6 MB/s eta 0:00:05
#      ----------------------------- ------- 458.5/568.0 MB 28.6 MB/s eta 0:00:04
#      ------------------------------ ------ 464.3/568.0 MB 28.7 MB/s eta 0:00:04
#      ------------------------------ ------ 471.6/568.0 MB 29.0 MB/s eta 0:00:04
#      ------------------------------- ----- 478.2/568.0 MB 29.1 MB/s eta 0:00:04
#      ------------------------------- ----- 484.2/568.0 MB 29.1 MB/s eta 0:00:03
#      -------------------------------- ---- 491.3/568.0 MB 29.0 MB/s eta 0:00:03
#      -------------------------------- ---- 497.8/568.0 MB 29.1 MB/s eta 0:00:03
#      -------------------------------- ---- 503.3/568.0 MB 29.1 MB/s eta 0:00:03
#      --------------------------------- --- 510.7/568.0 MB 29.4 MB/s eta 0:00:02
#      --------------------------------- --- 517.5/568.0 MB 29.4 MB/s eta 0:00:02
#      ---------------------------------- -- 524.0/568.0 MB 29.4 MB/s eta 0:00:02
#      ---------------------------------- -- 530.1/568.0 MB 29.3 MB/s eta 0:00:02
#      ----------------------------------- - 537.4/568.0 MB 29.6 MB/s eta 0:00:02
#      ----------------------------------- - 544.7/568.0 MB 29.7 MB/s eta 0:00:01
#      ----------------------------------- - 550.2/568.0 MB 29.7 MB/s eta 0:00:01
#      ------------------------------------  558.1/568.0 MB 29.9 MB/s eta 0:00:01
#      ------------------------------------  564.1/568.0 MB 29.9 MB/s eta 0:00:01
#      ------------------------------------  567.8/568.0 MB 29.8 MB/s eta 0:00:01
#      ------------------------------------  567.8/568.0 MB 29.8 MB/s eta 0:00:01
#      ------------------------------------  567.8/568.0 MB 29.8 MB/s eta 0:00:01
#      ------------------------------------  567.8/568.0 MB 29.8 MB/s eta 0:00:01
#      ------------------------------------  567.8/568.0 MB 29.8 MB/s eta 0:00:01
#      ------------------------------------  567.8/568.0 MB 29.8 MB/s eta 0:00:01
#      ------------------------------------- 568.0/568.0 MB 26.3 MB/s eta 0:00:00
# Installing collected packages: es-core-news-lg
# Successfully installed es-core-news-lg-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_lg')

# %%
'''
Versiones compatibles
Despues hay que reiniciar el entorno de ejecución
'''
# !pip install spacy
# !pip install textacy

# # Para siguientes ejecuciones, solo ejecutar esto y reiniciar despues el entorno
# !python -m spacy download en_core_web_lg
# !python -m spacy download es_core_news_lg
# Out:
# '\nVersiones compatibles\nDespues hay que reiniciar el entorno de ejecución\n'

# %% [markdown]
# # Spacy
# https://spacy.io/
#
# NOTA: Recuerda reiniciar el entorno de ejecucion despues de la instalacion

# %%
import spacy

nlp = spacy.load('en_core_web_lg')

# %% [markdown]
# ## Text basics
# Veamos como trabajar cn estos primeros ejemplos con la libreria ´spacy´. Cosas que podemos hacer:
# 1. Tokenizar en frases
# 2. Tokenizar en palabras
# 3. Acceder a los atributos de cada token
# 4. Acceder a las entidades del texto
# 5. Visualizar las entidades del texto

# %%
# The text we want to examine
text = """
London is the capital and most populous city of England and 
the United Kingdom.  Standing on the River Thames in the south east 
of the island of Great Britain, London has been a major settlement 
for two millennia. It was founded by the Romans, who named it Londinium.
"""

doc = nlp(text)

print(doc)

for num, sentence in enumerate(doc.sents):
  print(num, sentence)
# Out:
# London is the capital and most populous city of England and
# the United Kingdom.  Standing on the River Thames in the south east
# of the island of Great Britain, London has been a major settlement
# for two millennia. It was founded by the Romans, who named it Londinium.
#
# 0
#
# 1 London is the capital and most populous city of England and
# the United Kingdom.
# 2 Standing on the River Thames in the south east
# of the island of Great Britain, London has been a major settlement
# for two millennia.
# 3 It was founded by the Romans, who named it Londinium.

# %%
len(list(doc.sents))
# Out:
# 4

# %%
for word in doc[:20]:
  print(word.text, word.lemma_, word.pos_, word.is_stop)
# Out:
#
#  SPACE False
# London London PROPN False
# is be AUX True
# the the DET True
# capital capital NOUN False
# and and CCONJ True
# most most ADV True
# populous populous ADJ False
# city city NOUN False
# of of ADP True
# England England PROPN False
# and and CCONJ True
#
#
#  SPACE False
# the the DET True
# United United PROPN False
# Kingdom Kingdom PROPN False
# . . PUNCT False
#     SPACE False
# Standing stand VERB False
# on on ADP True

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %% [markdown]
# ## Syntactic analysis
# Doing the school homework

# %%
from spacy import displacy

doc2 = nlp("London is the capital and most populous city of England and the United Kingdom")
displacy.render(doc2, jupyter=True, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6c1e47ee30c1450a81be193fac5a89b8-0" class="displacy" width="2500" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">London</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">capital</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">populous</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">city</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">England</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">United</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">Kingdom</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6c1e47ee30c1450a81be193fac5a89b8-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6c1e47ee30c1450a81be193fac5a89b8-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6c1e47ee30c1450a81be193fac5a89b8-0-1" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6c1e47ee30c1450a81be193fac5a89b8-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6c1e47ee30c1450a81be193fac5a89b8-0-2" stroke-width="2px" d="M245,264.5 C245,89.5 570.0,89.5 570.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6c1e47ee30c1450a81be193fac5a89b8-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570.0,266.5 L578.0,254.5 562.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6c1e47ee30c1450a81be193fac5a89b8-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6c1e47ee30c1450a81be193fac5a89b8-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M740.0,266.5 L748.0,254.5 732.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6c1e47ee30c1450a81be193fac5a89b8-0-4" stroke-width="2px" d="M945,264.5 C945,177.0 1090.0,177.0 1090.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6c1e47ee30c1450a81be193fac5a89b8-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,266.5 L937,254.5 953,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6c1e47ee30c1450a81be193fac5a89b8-0-5" stroke-width="2px" d="M1120,264.5 C1120,177.0 1265.0,177.0 1265.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6c1e47ee30c1450a81be193fac5a89b8-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,266.5 L1112,254.5 1128,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6c1e47ee30c1450a81be193fac5a89b8-0-6" stroke-width="2px" d="M595,264.5 C595,89.5 1270.0,89.5 1270.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6c1e47ee30c1450a81be193fac5a89b8-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1270.0,266.5 L1278.0,254.5 1262.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6c1e47ee30c1450a81be193fac5a89b8-0-7" stroke-width="2p

# %% [markdown]
# ## Entities in text

# %%
for entity in doc.ents:
  print(entity.text, entity.label_, spacy.explain(entity.label_))
# Out:
# London GPE Countries, cities, states
# England GPE Countries, cities, states
# the United Kingdom GPE Countries, cities, states
# south east LOC Non-GPE locations, mountain ranges, bodies of water
# Great Britain GPE Countries, cities, states
# London GPE Countries, cities, states
# two millennia DATE Absolute or relative dates or periods
# Romans NORP Nationalities or religious or political groups
# Londinium PERSON People, including fictional

# %%
# Doubts with labels
spacy.explain('ORG')
# Out:
# 'Companies, agencies, institutions, etc.'

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"><br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     London
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is the capital and most populous city of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     England
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and <br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United Kingdom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .  Standing on the River Thames in the
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     south east
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  <br>of the island of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Great Britain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     London
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  has been a major settlement <br>for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two millennia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . It was founded by the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Romans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# , who named it
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Londinium
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .<br></div></span>

# %% [markdown]
# ## Replacing names
# Hide names for GDPR

# %%
# Replace a token with "REDACTED" if it is a name
def replace_name_with_placeholder(token):
    if token.ent_iob != 0 and token.ent_type_ == "PERSON":
        return "GDPR"
    else:
        return token.text

# Loop through all the entities in a document and check if they are names
def scrub(text):
    doc = nlp(text)
    with doc.retokenize() as retokenizer:
        for ent in doc.ents:
            retokenizer.merge(ent)
    tokens = map(replace_name_with_placeholder, doc)
    return " ".join(tokens)

s = """
In 1950, Alan Turing published his famous article "Computing Machinery and Intelligence". In 1957, Noam Chomsky’s 
Syntactic Structures revolutionized Linguistics with 'universal grammar', a rule based system of syntactic structures.
"""

print(scrub(s))
# Out:
#  In 1950 , GDPR published his famous article "Computing Machinery and Intelligence " . In 1957 , GDPR
#  Syntactic Structures revolutionized Linguistics with ' universal grammar ' , a rule based system of syntactic structures .

# %% [markdown]
# ## Lematize

# %%
for w in doc:
  print(w.text, w.lemma_, w.pos_)
# Out:
#
#  SPACE
# London London PROPN
# is be AUX
# the the DET
# capital capital NOUN
# and and CCONJ
# most most ADV
# populous populous ADJ
# city city NOUN
# of of ADP
# England England PROPN
# and and CCONJ
#
#
#  SPACE
# the the DET
# United United PROPN
# Kingdom Kingdom PROPN
# . . PUNCT
#     SPACE
# Standing stand VERB
# on on ADP
# the the DET
# River River PROPN
# Thames Thames PROPN
# in in ADP
# the the DET
# south south PROPN
# east east PROPN
#
#
#  SPACE
# of of ADP
# the the DET
# island island NOUN
# of of ADP
# Great Great PROPN
# Britain Britain PROPN
# , , PUNCT
# London London PROPN
# has have AUX
# been be AUX
# a a DET
# major major ADJ
# settlement settlement NOUN
#
#
#  SPACE
# for for ADP
# two two NUM
# millennia millennium NOUN
# . . PUNCT
# It it PRON
# was be AUX
# founded found VERB
# by by ADP
# the the DET
# Romans Romans PROPN
# , , PUNCT
# who who PRON
# named name VERB
# it it PRON
# Londinium Londinium PROPN
# . . PUNCT
#
#
#  SPACE

# %% [markdown]
# ## Stopwords

# %%
from spacy.lang.en.stop_words import STOP_WORDS

print(list(STOP_WORDS)[:20])
# Out:
# ['using', 'herein', 'becomes', 'via', 'should', 'hereupon', 'more', 'over', 'onto', 'beforehand', 'others', 'its', 'put', 'n’t', 'in', 'four', '’d', 'fifteen', 'five', 'will']

# %%
lista_clean = [palabra for palabra in doc if not palabra.is_stop and not palabra.is_punct]
print(lista_clean)
# Out:
# [
# , London, capital, populous, city, England,
# , United, Kingdom,  , Standing, River, Thames, south, east,
# , island, Great, Britain, London, major, settlement,
# , millennia, founded, Romans, named, Londinium,
# ]

# %% [markdown]
# # Spanish
# ## Spacy  and entities

# %%
nlp_es = spacy.load('es_core_news_lg')

text = '''Londres (en inglés, London, pronunciado /ˈlʌndən/ ( escuchar)) es la capital y mayor ciudad de Inglaterra y del Reino Unido.2​3​ Situada a orillas del río Támesis, Londres es un importante asentamiento humano desde que fue fundada por los romanos con el nombre de Londinium hace casi dos milenios.4​ El núcleo antiguo de la urbe, la City de Londres, conserva básicamente su perímetro medieval de una milla cuadrada. Desde el siglo XIX el nombre «Londres» también hace referencia a toda la metrópolis desarrollada alrededor de este núcleo.5​ El grueso de esta conurbación forma la región de Londres y el área administrativa del Gran Londres,6​ gobernado por el alcalde y la asamblea de Londres.7​
Londres es una ciudad global, uno de los centros neurálgicos en el ámbito de las artes, el comercio, la educación, el entretenimiento, la moda, las finanzas, los medios de comunicación, la investigación, el turismo o el transporte.8​ Es el principal centro financiero del mundo9​10​11​ y una de las áreas metropolitanas con mayor PIB.12​13​ Londres es también una capital cultural mundial,14​15​16​17​ la ciudad más visitada considerando el número de visitas internacionales18​ y tiene el mayor sistema aeroportuario del mundo según el tráfico de pasajeros.19​ Asimismo, las 43 universidades de la ciudad conforman la mayor concentración de centros de estudios superiores de toda Europa.20​ En el año 2012 Londres se convirtió en la única ciudad en albergar la celebración de tres Juegos Olímpicos de Verano.21​
En esta ciudad multirracial convive gente de un gran número de culturas que hablan más de trescientos idiomas distintos.22​ La Autoridad del Gran Londres estima que en 2015 la ciudad tiene 8,63 millones de habitantes,23​ que supone el 12,5 % del total de habitantes del Reino Unido.24​ El área urbana del Gran Londres, con 10 470 00025​ habitantes, es la segunda más grande de Europa, pero su área metropolitana, con una población estimada de entre 12 y 14 millones,26​27​ es la mayor del continente. Desde 1831 a 1925 Londres, como capital del Imperio británico, fue la ciudad más poblada del mundo.'''
doc = nlp_es(text)

# Para ver las entidades que ha detectado
for entity in doc.ents:
    print(f"{entity.text} ({entity.label_})")
# Out:
# Londres (LOC)
# London (LOC)
# Inglaterra (LOC)
# Reino Unido.2​3​ Situada (LOC)
# Támesis (LOC)
# Londres (LOC)
# Londinium (LOC)
# El núcleo antiguo de la urbe (MISC)
# City de Londres (LOC)
# Londres (LOC)
# Londres (LOC)
# Gran Londres,6​ (LOC)
# Londres.7​
# Londres (LOC)
# Londres (LOC)
# Londres (LOC)
# Juegos Olímpicos de Verano.21​
# En esta ciudad multirracial convive gente de un gran número de culturas (MISC)
# La Autoridad del Gran Londres (MISC)
# Reino Unido.24​ El área urbana del (LOC)
# Gran Londres (LOC)
# Europa (LOC)
# Londres (LOC)
# Imperio británico (LOC)

# %%
# Doubts with labels
spacy.explain('MISC')
# Out:
# 'Miscellaneous entities, e.g. events, nationalities, products or works of art'

# %% [markdown]
# ## Most frequent words
# In a Wikipedia page

# %%
#%pip install wikipedia
# Out:
# Collecting wikipedia
#   Using cached wikipedia-1.4.0.tar.gz (27 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting beautifulsoup4 (from wikipedia)
#   Using cached beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from wikipedia) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2025.4.26)
# Collecting soupsieve>1.2 (from beautifulsoup4->wikipedia)
#   Using cached soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\alberto romero\appdata\roaming\python\python310\site-packages (from beautifulsoup4->wikipedia) (4.13.2)
# Using cached beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Using cached soupsieve-2.7-py3-none-any.whl (36 kB)
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (pyproject.toml): started
#   Building wheel for wikipedia (pyproject.toml): finished with status 'done'
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11783 sha256=432fd230d110c35df454fe9c931a65f23be4814fccaaf3a39768caf68df3a179
#   Stored in directory: c:\users\alberto romero\appdata\local\pip\cache\wheels\5e\b6\c5\93f3dec388ae76edc830cb42901bb0232504dfc0df02fc50de
# Successfully built wikipedia
# Installing collected packages: soupsieve, beautifulsoup4, wikipedia
#
#    ------------- -------------------------- 1/3 [beautifulsoup4]
#    ------------- -------------------------- 1/3 [beautifulsoup4]
#    ------------- -------------------------- 1/3 [beautifulsoup4]
#    ------------- -------------------------- 1/3 [beautifulsoup4]
#    ------------- -------------------------- 1/3 [beautifulsoup4]
#    -------------------------- ------------- 2/3 [wikipedia]
#    ---------------------------------------- 3/3 [wikipedia]
#
# Successfully installed beautifulsoup4-4.13.4 soupsieve-2.7 wikipedia-1.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from spacy.lang.es.stop_words import STOP_WORDS

# %%
list(STOP_WORDS)[:20]
# Out:
# ['además',
#  'cuántos',
#  'hemos',
#  'dado',
#  'os',
#  'durante',
#  'hizo',
#  'parte',
#  'gran',
#  'despacio',
#  'este',
#  'dónde',
#  'consigue',
#  'tambien',
#  'para',
#  'estado',
#  'ningún',
#  'hace',
#  'propia',
#  'sino']

# %%
import wikipedia
wikipedia.set_lang("en")
wiki = wikipedia.page(title="Data Science")
text = wiki.content
text[0:1000]
# Out:
# 'Data science is an interdisciplinary academic field that uses statistics, scientific computing, scientific methods, processing, scientific visualization, algorithms and systems to extract or extrapolate knowledge from potentially noisy, structured, or unstructured data. \nData science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine). Data science is multifaceted and can be described as a science, a research paradigm, a research method, a discipline, a workflow, and a profession.\nData science is "a concept to unify statistics, data analysis, informatics, and their related methods" to "understand and analyze actual phenomena" with data. It uses techniques and theories drawn from many fields within the context of mathematics, statistics, computer science, information science, and domain knowledge. However, data science is different from computer science and information science. Turing Award winner Jim Gra'

# %%
nombres = [w.text.lower() for w in nlp(text) if ((not w.is_stop) and (not w.is_punct) and (w.pos_ == 'NOUN'))]
nombres[:10]
# Out:
# ['data',
#  'science',
#  'field',
#  'statistics',
#  'computing',
#  'methods',
#  'processing',
#  'visualization',
#  'algorithms',
#  'systems']

# %%
from collections import Counter
word_freq = Counter(nombres)

word_freq.most_common(10)[1:]
# Out:
# [('science', 37),
#  ('statistics', 13),
#  ('=', 13),
#  ('analysis', 9),
#  ('information', 7),
#  ('computing', 6),
#  ('knowledge', 6),
#  ('field', 5),
#  ('methods', 4)]

# %%
wikipedia.set_lang("es")
wiki = wikipedia.page(title="Regresión Lineal")
text = wiki.content
text[0:1000]
# Out:
# 'En estadística, la regresión lineal o ajuste lineal es un modelo matemático usado para aproximar la relación de dependencia entre una variable dependiente \n  \n    \n      \n        Y\n      \n    \n    {\\displaystyle Y}\n  \n, \n  \n    \n      \n        m\n      \n    \n    {\\displaystyle m}\n  \n variables independientes \n  \n    \n      \n        \n          X\n          \n            i\n          \n        \n      \n    \n    {\\displaystyle X_{i}}\n  \n con \n  \n    \n      \n        m\n        ∈\n        \n          \n            Z\n          \n          \n            +\n          \n        \n      \n    \n    {\\displaystyle m\\in \\mathbb {Z} ^{+}}\n  \n y un término aleatorio \n  \n    \n      \n        ε\n      \n    \n    {\\displaystyle \\varepsilon }\n  \n. Este método es aplicable en muchas situaciones en las que se estudia la relación entre dos o más variables o predecir un comportamiento, algunas incluso sin relación con la tecnología. En caso de que no se pueda aplicar un modelo de regresión a un estudio, se dice que no hay corr'

# %%
nombres = [w.lemma_ for w in nlp_es(text) if ((not w.is_stop) and (not w.is_punct) and (w.pos_ == 'ADJ'))]
nombres[:10]
# Out:
# ['lineal',
#  'lineal',
#  'matemático',
#  'usado',
#  'dependiente',
#  'independiente',
#  '\\displaystyle',
#  '\\displaystyle',
#  'aleatorio',
#  'aplicable']

# %%
from collections import Counter
word_freq = Counter(nombres)

word_freq.most_common(10)[1:]
# Out:
# [('obtenido', 11),
#  ('\\displaystyle', 8),
#  ('múltiple', 8),
#  ('independiente', 7),
#  ('cuadrado', 7),
#  ('simple', 7),
#  ('dependiente', 6),
#  ('aleatorio', 6),
#  ('llamado', 6)]

# %% [markdown]
# ## Textacy London text
# Now we want to know things about London, from our previous text

# %%
#%pip install numpy==1.26.4
# then restart

# %%
# !pip install textacy==0.12.0
# Out:
# Collecting textacy==0.12.0
#   Using cached textacy-0.12.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: cachetools>=4.0.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy==0.12.0) (5.5.2)
# Requirement already satisfied: catalogue~=2.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy==0.12.0) (2.0.10)
# Requirement already satisfied: cytoolz>=0.10.1 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy==0.12.0) (1.0.1)
# Requirement already satisfied: jellyfish>=0.8.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy==0.12.0) (1.2.0)
# Requirement already satisfied: joblib>=0.13.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy==0.12.0) (1.5.0)
# Requirement already satisfied: networkx>=2.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy==0.12.0) (3.4.2)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy==0.12.0) (2.2.5)
# Requirement already satisfied: pyphen>=0.10.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy==0.12.0) (0.17.2)
# Requirement already satisfied: requests>=2.10.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy==0.12.0) (2.32.3)
# Requirement already satisfied: scipy>=0.17.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy==0.12.0) (1.15.2)
# Requirement already satisfied: scikit-learn>=0.19.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy==0.12.0) (1.6.1)
# Requirement already satisfied: spacy>=3.0.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy==0.12.0) (3.8.5)
# Requirement already satisfied: tqdm>=4.19.6 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from textacy==0.12.0) (4.67.1)
# Requirement already satisfied: toolz>=0.8.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from cytoolz>=0.10.1->textacy==0.12.0) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.10.0->textacy==0.12.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.10.0->textacy==0.12.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.10.0->textacy==0.12.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.10.0->textacy==0.12.0) (2025.4.26)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=0.19.0->textacy==0.12.0) (3.6.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy>=3.0.0->textacy==0.12.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy>=3.0.0->textacy==0.12.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy>=3.0.0->textacy==0.12.0) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy>=3.0.0->textacy==0.12.0) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy>=3.0.0->textacy==0.12.0) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy>=3.0.0->textacy==0.12.0) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy>=3.0.0->textacy==0.12.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy>=3.0.0->textacy==0.12.0) (2.5.1)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy>=3.0.0->textacy==0.12.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy>=3.0.0->textacy==0.12.0) (0.15.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy>=3.0.0->textacy==0.12.0) (2.11.4)
# Requirement already satisfied: jinja2 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy>=3.0.0->textacy==0.12.0) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy>=3.0.0->textacy==0.12.0) (57.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\alberto romero\appdata\roaming\python\python310\site-packages (from spacy>=3.0.0->textacy==0.12.0) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from spacy>=3.0.0->textacy==0.12.0) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy>=3.0.0->textacy==0.12.0) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0.0->textacy==0.12.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0.0->textacy==0.12.0) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\alberto romero\appdata\roaming\python\python310\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0.0->textacy==0.12.0) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0.0->textacy==0.12.0) (0.4.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy>=3.0.0->textacy==0.12.0) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy>=3.0.0->textacy==0.12.0) (0.1.5)
# Requirement already satisfied: colorama in c:\users\alberto romero\appdata\roaming\python\python310\site-packages (from tqdm>=4.19.6->textacy==0.12.0) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy>=3.0.0->textacy==0.12.0) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy>=3.0.0->textacy==0.12.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy>=3.0.0->textacy==0.12.0) (14.0.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy>=3.0.0->textacy==0.12.0) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy>=3.0.0->textacy==0.12.0) (7.1.0)
# Requirement already satisfied: wrapt in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy>=3.0.0->textacy==0.12.0) (1.17.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy>=3.0.0->textacy==0.12.0) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3.0.0->textacy==0.12.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\alberto romero\appdata\roaming\python\python310\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3.0.0->textacy==0.12.0) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3.0.0->textacy==0.12.0) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\alberto romero\appdata\local\programs\python\python310\lib\site-packages (from jinja2->spacy>=3.0.0->textacy==0.12.0) (3.0.2)
# Downloading textacy-0.12.0-py3-none-any.whl (208 kB)
# Installing collected packages: textacy
#   Attempting uninstall: textacy
#     Found existing installation: textacy 0.13.0
#     Uninstalling textacy-0.13.0:
#       Successfully uninstalled textacy-0.13.0
# Successfully installed textacy-0.12.0

# %%
#%pip install numpy==1.26.4

# %%
# import spacy
import textacy.extract

#### CODE ####

# The text we want to examine
text = """London is the capital and most populous city of England and the United Kingdom. Standing on the River Thames in the south east of the island of Great Britain, London has been a major settlement for two millennia. London was founded by the Romans, 
who named it Londinium. London is a huge city. London has a lot of cute restaurants. Jaimito is my best friend.
"""

doc = nlp(text)
statements = textacy.extract.semistructured_statements(doc, entity="London", cue='be')

# Print the results
print("Here are the things I know about London:")

for statement in statements:
    subject, verb, fact = statement
    print(f" - {fact}")
# Out:
# Here are the things I know about London:
#  - [the, capital, and, most, populous, city, of, England, and, the, United, Kingdom]
#  - [a, major, settlement, for, two, millennia]
#  - [a, huge, city]

# %% [markdown]
# ## Textacy with Wikipedia API
# We don't want the most frequent words, we want sentences about London

# %%
wikipedia.set_lang("en")
london = wikipedia.page("London")
text = london.content

# %%
doc = nlp(text)

# Extract semi-structured statements
statements = textacy.extract.semistructured_statements(doc, entity="London Underground", cue='be')

# Print the results
print("Here are the things I know about London:")

for statement in statements:
    subject, verb, fact = statement
    print(f" - {fact}")
# Out:
# Here are the things I know about London:
#  - [the, world, 's, oldest, rapid, transit, system]
